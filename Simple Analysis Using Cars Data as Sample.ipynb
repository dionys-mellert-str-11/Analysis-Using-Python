# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv('cars.csv', delimiter=';')
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %% [markdown]
# Check if there is a missing data

# %%
df.isnull().sum()
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# dtype: int64

# %% [markdown]
# look at specific column

# %%
df['Car'].head()
# Out:
# 0                       STRING
# 1    Chevrolet Chevelle Malibu
# 2            Buick Skylark 320
# 3           Plymouth Satellite
# 4                AMC Rebel SST
# Name: Car, dtype: object

# %% [markdown]
# Pull name of the column

# %%
df.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %% [markdown]
# view specific row using "loc"

# %%
df.loc[20:25]
# Out:
#                         Car   MPG Cylinders Displacement Horsepower Weight  \
# 20  Buick Estate Wagon (sw)  14.0         8        455.0      225.0  3086.
# 21   Toyota Corolla Mark ii  24.0         4        113.0      95.00  2372.
# 22          Plymouth Duster  22.0         6        198.0      95.00  2833.
# 23               AMC Hornet  18.0         6        199.0      97.00  2774.
# 24            Ford Maverick  21.0         6        200.0      85.00  2587.
# 25             Datsun PL510  27.0         4        97.00      88.00  2130.
#
#    Acceleration Model Origin
# 20         10.0    70     US
# 21         15.0    70  Japan
# 22         15.5    70     US
# 23         15.5    70     US
# 24         16.0    70     US
# 25         14.5    70  Japan

# %% [markdown]
# call the data (first 5 rows) where the origin is "Japan"

# %%
df[df['Origin'].str.contains('Japan')].head(5)
# Out:
#                        Car   MPG Cylinders Displacement Horsepower Weight  \
# 21  Toyota Corolla Mark ii  24.0         4        113.0      95.00  2372.
# 25            Datsun PL510  27.0         4        97.00      88.00  2130.
# 36            Datsun PL510  27.0         4        97.00      88.00  2130.
# 38          Toyota Corolla  25.0         4        113.0      95.00  2228.
# 61     Toyota Corolla 1200  31.0         4        71.00      65.00  1773.
#
#    Acceleration Model Origin
# 21         15.0    70  Japan
# 25         14.5    70  Japan
# 36         14.5    71  Japan
# 38         14.0    71  Japan
# 61         19.0    71  Japan

# %% [markdown]
# Split column 'Car' to get "brand" and "model"

# %%
df[['Brand', 'Type']] = df['Car'].str.split(n=1, expand=True)

# %%
df.head(5)
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin      Brand             Type
# 0  DOUBLE       DOUBLE   INT    CAT     STRING             None
# 1   3504.         12.0    70     US  Chevrolet  Chevelle Malibu
# 2   3693.         11.5    70     US      Buick      Skylark 320
# 3   3436.         11.0    70     US   Plymouth        Satellite
# 4   3433.         12.0    70     US        AMC        Rebel SST

# %% [markdown]
# Count total Brand in the dataset

# %%
Brand = df.Brand
Brand.value_counts()
# Out:
# Ford             53
# Chevrolet        45
# Plymouth         32
# AMC              29
# Dodge            28
# Toyota           26
# Datsun           23
# Volkswagen       23
# Buick            17
# Pontiac          16
# Honda            13
# Mazda            12
# Mercury          11
# Oldsmobile       10
# Fiat              8
# Peugeot           8
# Audi              7
# Volvo             6
# Chrysler          6
# Renault           5
# Saab              5
# Opel              4
# Subaru            4
# BMW               2
# Cadillac          2
# Chevy             2
# Mercedes-Benz     2
# Triumph           1
# Mercedes          1
# STRING            1
# Hi                1
# Capri             1
# Chevrolete        1
# Citroen           1
# Nissan            1
# Name: Brand, dtype: int64

# %% [markdown]
# Plot top 5 Brands

# %%
df.Brand.value_counts().head(5).plot.bar()
plt.title("Top 5 car brands on sale")
# Out:
# Text(0.5, 1.0, 'Top 5 car brands on sale')
